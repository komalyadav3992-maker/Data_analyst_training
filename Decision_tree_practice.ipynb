# %%
import pandas as pd
import numpy as np
from sklearn.tree import DecisionTreeClassifier, plot_tree
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, confusion_matrix, classification_report
import matplotlib.pyplot as plt

# %%
data={'Age':[25,30,45,35,50,23,40],
      'Income': [30000, 60000, 80000, 120000, 20000, 40000, 90000],
      'CreditScore': [650, 720, 690, 780, 600, 680, 750],
      'LoanApproved': [0, 1, 1, 1, 0, 0, 1]
}

# %%
df=pd.DataFrame(data)

# %%
# x and y defined
x=df[['Age','Income','CreditScore']]
y=df['LoanApproved']

# %%
# train test split
x_train, x_test, y_train, y_test = train_test_split(x,y,test_size=0.2 ,random_state=42)

# %%
model = DecisionTreeClassifier()
model.fit(x_train, y_train)
# Out:
# DecisionTreeClassifier()

# %%
# prediction and accuracy
y_pred=model.predict(x_test)
print("Accuracy:",accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.5

# %%
# Decision of new customer
new_customer = [[28, 70000, 750]]  # Age, Income, CreditScore
result = model.predict(new_customer)
if result[0] == 1:
    print("Loan Approved ")
else:
    print("Loan Rejected ")
# Out:
# Loan Approved
# /usr/local/lib/python3.12/dist-packages/sklearn/utils/validation.py:2739: UserWarning: X does not have valid feature names, but DecisionTreeClassifier was fitted with feature names
#   warnings.warn(

# %%
plt.figure(figsize=(10,6))
plot_tree(model, feature_names=x.columns, class_names=['Rejected', 'Approved'], filled=True, rounded=True)
plt.show()
